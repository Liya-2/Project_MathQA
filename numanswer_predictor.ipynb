# %%
import pandas as pd

cols_headers = ["Question", "Answer", "Option-1", "Option-2", "Option-3", "Option-4", "Option-5"]
pd.read_csv('train.tsv', names=cols_headers, sep='\t')
# Out:
#                                                 Question  Answer  Option-1  \
# 0       "the banker ' s gain of a certain sum due 3 y...       0  0.258065
# 1       "average age of students of an adult school i...       3  0.625000
# 2       "sophia finished 2 / 3 of a book. she calcula...       1  0.119085
# 3                         "120 is what percent of 50 ?",       1  0.006274
# 4       "there are 10 girls and 20 boys in a classroo...       0  0.066667
# ...                                                  ...     ...       ...
# 30259   "the speed of a car is 60 km in the first hou...       0  0.125000
# 30260   "how many figures are required for numbering ...       2  0.208521
# 30261   "in how many ways 2 boys and 2 girls can be s...       1  0.155556
# 30262   "for what value of x,is | x \u2013 3 | + | x ...       4  0.000000
# 30263   "the ratio of number of boys and girls in a s...       3  0.138889
#
#        Option-2  Option-3  Option-4  Option-5
# ...
